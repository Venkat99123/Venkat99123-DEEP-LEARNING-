# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('/kaggle/input/naveen/PRSA_data_2010.1.1-2014.12.31.csv')
df.head()
# Out:
#    No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd    Iws  Is  Ir
# 0   1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW   1.79   0   0
# 1   2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW   4.92   0   0
# 2   3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW   6.71   0   0
# 3   4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW   9.84   0   0
# 4   5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW  12.97   0   0

# %%
df.drop(['No'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd    Iws  Is  Ir
# 0  2010      1    1     0    NaN   -21 -11.0  1021.0   NW   1.79   0   0
# 1  2010      1    1     1    NaN   -21 -12.0  1020.0   NW   4.92   0   0
# 2  2010      1    1     2    NaN   -21 -11.0  1019.0   NW   6.71   0   0
# 3  2010      1    1     3    NaN   -21 -14.0  1019.0   NW   9.84   0   0
# 4  2010      1    1     4    NaN   -20 -12.0  1018.0   NW  12.97   0   0

# %%
df.describe()
# Out:
#                year         month           day          hour         pm2.5  \
# count  43824.000000  43824.000000  43824.000000  43824.000000  41757.000000
# mean    2012.000000      6.523549     15.727820     11.500000     98.613215
# std        1.413842      3.448572      8.799425      6.922266     92.050387
# min     2010.000000      1.000000      1.000000      0.000000      0.000000
# 25%     2011.000000      4.000000      8.000000      5.750000     29.000000
# 50%     2012.000000      7.000000     16.000000     11.500000     72.000000
# 75%     2013.000000     10.000000     23.000000     17.250000    137.000000
# max     2014.000000     12.000000     31.000000     23.000000    994.000000
#
#                DEWP          TEMP          PRES           Iws            Is  \
# count  43824.000000  43824.000000  43824.000000  43824.000000  43824.000000
# mean       1.817246     12.448521   1016.447654     23.889140      0.052734
# ...

# %%
df.isnull().sum()
# Out:
# year        0
# month       0
# day         0
# hour        0
# pm2.5    2067
# DEWP        0
# TEMP        0
# PRES        0
# cbwd        0
# Iws         0
# Is          0
# Ir          0
# dtype: int64

# %%
# fill the null values where it present in the datset with using of zero digits 
df['pm2.5'] = df['pm2.5'].fillna(0)

# %%
df.isnull().sum()
# Out:
# year     0
# month    0
# day      0
# hour     0
# pm2.5    0
# DEWP     0
# TEMP     0
# PRES     0
# cbwd     0
# Iws      0
# Is       0
# Ir       0
# dtype: int64

# %%
df.head()
# Out:
#    year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd    Iws  Is  Ir
# 0  2010      1    1     0    0.0   -21 -11.0  1021.0   NW   1.79   0   0
# 1  2010      1    1     1    0.0   -21 -12.0  1020.0   NW   4.92   0   0
# 2  2010      1    1     2    0.0   -21 -11.0  1019.0   NW   6.71   0   0
# 3  2010      1    1     3    0.0   -21 -14.0  1019.0   NW   9.84   0   0
# 4  2010      1    1     4    0.0   -20 -12.0  1018.0   NW  12.97   0   0

# %%
df.tail()
# Out:
#        year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  Is  Ir
# 43819  2014     12   31    19    8.0   -23  -2.0  1034.0   NW  231.97   0   0
# 43820  2014     12   31    20   10.0   -22  -3.0  1034.0   NW  237.78   0   0
# 43821  2014     12   31    21   10.0   -22  -3.0  1034.0   NW  242.70   0   0
# 43822  2014     12   31    22    8.0   -22  -4.0  1034.0   NW  246.72   0   0
# 43823  2014     12   31    23   12.0   -21  -3.0  1034.0   NW  249.85   0   0

# %%
df['datetime'] = pd.to_datetime(df[['year', 'month', 'day', 'hour']])
df
# Out:
#        year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  Is  Ir  \
# 0      2010      1    1     0    0.0   -21 -11.0  1021.0   NW    1.79   0   0
# 1      2010      1    1     1    0.0   -21 -12.0  1020.0   NW    4.92   0   0
# 2      2010      1    1     2    0.0   -21 -11.0  1019.0   NW    6.71   0   0
# 3      2010      1    1     3    0.0   -21 -14.0  1019.0   NW    9.84   0   0
# 4      2010      1    1     4    0.0   -20 -12.0  1018.0   NW   12.97   0   0
# ...     ...    ...  ...   ...    ...   ...   ...     ...  ...     ...  ..  ..
# 43819  2014     12   31    19    8.0   -23  -2.0  1034.0   NW  231.97   0   0
# 43820  2014     12   31    20   10.0   -22  -3.0  1034.0   NW  237.78   0   0
# 43821  2014     12   31    21   10.0   -22  -3.0  1034.0   NW  242.70   0   0
# 43822  2014     12   31    22    8.0   -22  -4.0  1034.0   NW  246.72   0   0
# 43823  2014     12   31    23   12.0   -21  -3.0  1034.0   NW  249.85   0   0
#
#                  datetime
# ...

# %%
df = df.drop(['year','month','day','hour'],axis=1)

# %%
df
# Out:
#        pm2.5  DEWP  TEMP    PRES cbwd     Iws  Is  Ir            datetime
# 0        0.0   -21 -11.0  1021.0   NW    1.79   0   0 2010-01-01 00:00:00
# 1        0.0   -21 -12.0  1020.0   NW    4.92   0   0 2010-01-01 01:00:00
# 2        0.0   -21 -11.0  1019.0   NW    6.71   0   0 2010-01-01 02:00:00
# 3        0.0   -21 -14.0  1019.0   NW    9.84   0   0 2010-01-01 03:00:00
# 4        0.0   -20 -12.0  1018.0   NW   12.97   0   0 2010-01-01 04:00:00
# ...      ...   ...   ...     ...  ...     ...  ..  ..                 ...
# 43819    8.0   -23  -2.0  1034.0   NW  231.97   0   0 2014-12-31 19:00:00
# 43820   10.0   -22  -3.0  1034.0   NW  237.78   0   0 2014-12-31 20:00:00
# 43821   10.0   -22  -3.0  1034.0   NW  242.70   0   0 2014-12-31 21:00:00
# 43822    8.0   -22  -4.0  1034.0   NW  246.72   0   0 2014-12-31 22:00:00
# 43823   12.0   -21  -3.0  1034.0   NW  249.85   0   0 2014-12-31 23:00:00
#
# [43824 rows x 9 columns]

# %%
columns = df.columns.tolist()

# Move the last column to the first position
columns = [columns[-1]] + columns[:-1]

# Reorder the DataFrame columns
df = df[columns]

# %%
#changing the datetime into index
df.set_index('datetime',inplace=True)
df.columns = ['pollution', 'dew', 'temp', 'press', 'wnd_dir', 'wnd_spd', 'snow', 'rain']

# %%
df = df[24:]
df.head()
# Out:
#                      pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain
# datetime
# 2010-01-02 00:00:00      129.0  -16  -4.0  1020.0      SE     1.79     0     0
# 2010-01-02 01:00:00      148.0  -15  -4.0  1020.0      SE     2.68     0     0
# 2010-01-02 02:00:00      159.0  -11  -5.0  1021.0      SE     3.57     0     0
# 2010-01-02 03:00:00      181.0   -7  -5.0  1022.0      SE     5.36     1     0
# 2010-01-02 04:00:00      138.0   -7  -5.0  1022.0      SE     6.25     2     0

# %%
df.values
# Out:
# array([[129.0, -16, -4.0, ..., 1.79, 0, 0],
#        [148.0, -15, -4.0, ..., 2.68, 0, 0],
#        [159.0, -11, -5.0, ..., 3.57, 0, 0],
#        ...,
#        [10.0, -22, -3.0, ..., 242.7, 0, 0],
#        [8.0, -22, -4.0, ..., 246.72, 0, 0],
#        [12.0, -21, -3.0, ..., 249.85, 0, 0]], dtype=object)

# %%
import matplotlib.pyplot as plt

groups = [0, 1, 2, 3, 5, 6, 7]
num_groups = len(groups)

fig, axes = plt.subplots(num_groups, 1, figsize=(10, 10))

for i, group in enumerate(groups):
    ax = axes[i] if num_groups > 1 else axes
    ax.plot(df.values[:, group])
    ax.set_title(df.columns[group], y=0.5, loc='right')

fig.tight_layout()
plt.show()

# %%
from pandas import DataFrame, concat
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
catgorical = df.select_dtypes(include='object')

# %%
le =  LabelEncoder()

# %%
catgorical = le.fit_transform(catgorical)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
catgorical.dtype
# Out:
# dtype('int64')

# %%
df['wnd_dir']=catgorical

# %%
df.head()
# Out:
#                      pollution  dew  temp   press  wnd_dir  wnd_spd  snow  \
# datetime
# 2010-01-02 00:00:00      129.0  -16  -4.0  1020.0        2     1.79     0
# 2010-01-02 01:00:00      148.0  -15  -4.0  1020.0        2     2.68     0
# 2010-01-02 02:00:00      159.0  -11  -5.0  1021.0        2     3.57     0
# 2010-01-02 03:00:00      181.0   -7  -5.0  1022.0        2     5.36     1
# 2010-01-02 04:00:00      138.0   -7  -5.0  1022.0        2     6.25     2
#
#                      rain
# datetime
# 2010-01-02 00:00:00     0
# 2010-01-02 01:00:00     0
# 2010-01-02 02:00:00     0
# 2010-01-02 03:00:00     0
# 2010-01-02 04:00:00     0

# %%
from pandas import DataFrame, concat
import pandas as pd

def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    
    # Input sequence (t-n, ..., t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    
    # Forecast sequence (t, t+1, ..., t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    
    # Concatenate input and forecast sequences
    agg = concat(cols, axis=1)
    agg.columns = names
    
    # Drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    
    return agg

# %% [markdown]
# # In summary, this function takes a time series dataset and converts it into a tabular format suitable for supervised learning,
# # where each row represents a set of input observations and their corresponding output predictions.

# %%
# ensure all data is float
df = df.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(df)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)
# drop columns we don't want to predict
reframed.drop(reframed.columns[[9,10,11,12,13,14,15]], axis=1, inplace=True)
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.129779   0.352941   0.245902   0.527273   0.666667   0.002290
# 2   0.148893   0.367647   0.245902   0.527273   0.666667   0.003811
# 3   0.159960   0.426471   0.229508   0.545454   0.666667   0.005332
# 4   0.182093   0.485294   0.229508   0.563637   0.666667   0.008391
# 5   0.138833   0.485294   0.229508   0.563637   0.666667   0.009912
#
#    var7(t-1)  var8(t-1)   var1(t)
# 1   0.000000        0.0  0.148893
# 2   0.000000        0.0  0.159960
# 3   0.000000        0.0  0.182093
# 4   0.037037        0.0  0.138833
# 5   0.074074        0.0  0.109658

# %%
reframed.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.129779   0.352941   0.245902   0.527273   0.666667   0.002290
# 2   0.148893   0.367647   0.245902   0.527273   0.666667   0.003811
# 3   0.159960   0.426471   0.229508   0.545454   0.666667   0.005332
# 4   0.182093   0.485294   0.229508   0.563637   0.666667   0.008391
# 5   0.138833   0.485294   0.229508   0.563637   0.666667   0.009912
#
#    var7(t-1)  var8(t-1)   var1(t)
# 1   0.000000        0.0  0.148893
# 2   0.000000        0.0  0.159960
# 3   0.000000        0.0  0.182093
# 4   0.037037        0.0  0.138833
# 5   0.074074        0.0  0.109658

# %%
# split into train and test sets
values = reframed.values
n_train_hours = 365 * 24
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (8760, 1, 8) (8760,) (35039, 1, 8) (35039,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense

# %%
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 122/122 - 3s - 25ms/step - loss: 0.0548 - val_loss: 0.0554
# Epoch 2/50
# 122/122 - 1s - 9ms/step - loss: 0.0382 - val_loss: 0.0560
# Epoch 3/50
# 122/122 - 2s - 15ms/step - loss: 0.0232 - val_loss: 0.0466
# Epoch 4/50
# 122/122 - 2s - 20ms/step - loss: 0.0183 - val_loss: 0.0446
# Epoch 5/50
# 122/122 - 1s - 8ms/step - loss: 0.0164 - val_loss: 0.0328
# Epoch 6/50
# 122/122 - 2s - 13ms/step - loss: 0.0153 - val_loss: 0.0213
# Epoch 7/50
# 122/122 - 2s - 16ms/step - loss: 0.0149 - val_loss: 0.0184
# Epoch 8/50
# 122/122 - 1s - 9ms/step - loss: 0.0147 - val_loss: 0.0168
# Epoch 9/50
# 122/122 - 1s - 10ms/step - loss: 0.0147 - val_loss: 0.0158
# Epoch 10/50
# ...

# %%
# Assuming 'model' is already defined and trained
# 'test_X' is the input features for the test dataset
from sklearn.metrics import mean_squared_error
# Make predictions
yhat = model.predict(test_X)

# Reshape test_X if needed
test_X_reshaped = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Invert scaling for forecast
inv_yhat = np.concatenate((yhat, test_X_reshaped[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:, 0]

# Invert scaling for actual
test_y_reshaped = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y_reshaped, test_X_reshaped[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:, 0]

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
# Calculate MAE
mae = mean_absolute_error(inv_y, inv_yhat)
print('Test MAE: %.3f' % mae)

# Calculate R-squared
r2 = r2_score(inv_y, inv_yhat)
print('R-squared: %.3f' % r2)
# Out:
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Test RMSE: 26.472
# Test MAE: 13.361
# R-squared: 0.917
